# %% [markdown]
# ## Reading data from dataset

# %%
# For avoiding future warnings while training model
import pandas as pd
import numpy as np

import warnings
warnings.simplefilter('ignore', FutureWarning)

# %%
# Reading data from CSV
data = pd.read_csv('concrete_data.csv')
data.head()
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age  Strength
# 0            1040.0           676.0   28     79.99
# 1            1055.0           676.0   28     61.89
# 2             932.0           594.0  270     40.27
# 3             932.0           594.0  365     41.05
# 4             978.4           825.5  360     44.30

# %%
# Specifying columns for the predictors and target values
data_columns = data.columns
predictors = data[data_columns[data_columns != 'Strength']]
target = data['Strength']

# %%
target.head()
# Out:
# 0    79.99
# 1    61.89
# 2    40.27
# 3    41.05
# 4    44.30
# Name: Strength, dtype: float64

# %%
predictors.head()
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age
# 0            1040.0           676.0   28
# 1            1055.0           676.0   28
# 2             932.0           594.0  270
# 3             932.0           594.0  365
# 4             978.4           825.5  360

# %% [markdown]
# ## Normalizing the data

# %%
# Normalize data by subtracting the mean from the individual predictors and dividing by standard deviation
predictors_norm = (predictors - predictors.mean()) / predictors.std()
predictors_norm.head()
# Out:
#      Cement  Blast Furnace Slag   Fly Ash     Water  Superplasticizer  \
# 0  2.476712           -0.856472 -0.846733 -0.916319         -0.620147
# 1  2.476712           -0.856472 -0.846733 -0.916319         -0.620147
# 2  0.491187            0.795140 -0.846733  2.174405         -1.038638
# 3  0.491187            0.795140 -0.846733  2.174405         -1.038638
# 4 -0.790075            0.678079 -0.846733  0.488555         -1.038638
#
#    Coarse Aggregate  Fine Aggregate       Age
# 0          0.862735       -1.217079 -0.279597
# 1          1.055651       -1.217079 -0.279597
# 2         -0.526262       -2.239829  3.551340
# 3         -0.526262       -2.239829  5.055221
# 4          0.070492        0.647569  4.976069

# %% [markdown]
# ## Splitting the data

# %%
# Using Train Test Split from SKLEARN LIBRARY
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    predictors_norm, target, test_size=0.3, random_state=42)

# Training data = 70% and Testing Data = 30%

# %% [markdown]
# ## Building a Neural Network

# %%
# Importing the Keras Library for creating model
import keras
from keras.models import Sequential
from keras.layers import Dense

# %% [markdown]
# ## Train and Test the Network
# Here, we are creating a model which has 3 Hidden Layers of 10 nodes and Activation Function is ReLU. Optimizer is adam and Loss Function is mean_squared_error. We are storing the loss values in a list as well... there are 50 epochs

# %%
# create model
model = Sequential()
model.add(Dense(10, activation='relu', input_shape=(predictors_norm.shape[1],)))
model.add(Dense(10, activation='relu', input_shape=(predictors_norm.shape[1],)))
model.add(Dense(10, activation='relu', input_shape=(predictors_norm.shape[1],)))
model.add(Dense(1))

# compiling model with MSE as the Loss Function
model.compile(optimizer='adam', loss='mse')

# Train the model and store the history
history = model.fit(X_train, y_train, epochs=50)

# Storing the MSE values in the list
mse_list = history.history['loss']
# Out:
# C:\Users\Lakshya Saxena\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1570.5927
# Epoch 2/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1527.2053
# Epoch 3/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1554.1158
# Epoch 4/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1378.6794
# Epoch 5/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1285.0530
# Epoch 6/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1092.7343
# Epoch 7/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 910.4719
# Epoch 8/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 666.4620
# Epoch 9/50
# ...

# %%
print(mse_list)
# Out:
# [1548.22314453125, 1506.991455078125, 1448.0640869140625, 1360.6917724609375, 1236.6162109375, 1072.3819580078125, 870.106201171875, 649.1631469726562, 460.24835205078125, 342.1264343261719, 284.7186584472656, 254.78614807128906, 234.6688690185547, 219.07203674316406, 207.767333984375, 197.90432739257812, 189.9407958984375, 183.48236083984375, 177.39865112304688, 172.1776885986328, 167.49818420410156, 163.265625, 159.4445343017578, 155.84962463378906, 152.41073608398438, 149.2947998046875, 146.3460235595703, 143.7097625732422, 141.11099243164062, 138.7112579345703, 136.28439331054688, 133.62643432617188, 131.3188018798828, 128.76478576660156, 126.7072982788086, 124.3580551147461, 121.83573913574219, 120.08972930908203, 117.9334487915039, 115.69727325439453, 113.9057388305664, 111.54331970214844, 109.7450180053711, 107.70640563964844, 105.68917083740234, 103.74319458007812, 102.5511245727539, 100.21519470214844, 98.07046508789062, 96.44612884521484]

# %%
# Mean value of the Losses throughout the Training
print(np.mean(mse_list))
# Out:
# 328.8080578613281

# %%
# Standard Deviation of the Losses throughout the Training
print(np.std(mse_list))
# Out:
# 408.8877106876585
